# %% [markdown]
# <a href="https://colab.research.google.com/github/testdemodemotrial-hub/New/blob/main/Sample_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 5

sum = a + b

print("The answer is:", sum)
